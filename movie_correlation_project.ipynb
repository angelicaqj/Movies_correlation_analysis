# %% [markdown]
# # Movies Correlation Analysis

# %% [markdown]
# ## Import libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# data visualization
import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

# read in the data
movies_df = pd.read_csv("movies.csv")

# %% [markdown]
# ## Exploratory Analysis

# %%
# Let's look at the data

movies_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let's see if there is any missing data

for col in movies_df.columns:
    pct_missing = np.mean(movies_df[col].isnull())
    print('{} - {}%'.format(col, np.round(pct_missing,2)))

movies_df = movies_df.fillna(0) # replace NA values to 0
# Out:
# name - 0.0%
# rating - 0.01%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.28%
# gross - 0.02%
# company - 0.0%
# runtime - 0.0%

# %%
# data types for our columns

movies_df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of columns

movies_df['budget'] = movies_df['budget'].astype('int64')
movies_df['gross'] = movies_df['gross'].astype('int64')

# %%
movies_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# create correct year

# split the realesed column by comma
movies_df[['month', 'correct_year']] = movies_df['released'].astype(str).str.split(',', expand = True)

movies_df['correct_year'] = movies_df['correct_year'].str[:5]
movies_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movies_df.sort_values(by = ['gross'], inplace = False, ascending = False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates

movies_df['company'].drop_duplicates() # shows only the distinct values
# Out:
# 0                                            Warner Bros.
# 1                                       Columbia Pictures
# 2                                               Lucasfilm
# 3                                      Paramount Pictures
# 4                                          Orion Pictures
# 6                                      Universal Pictures
# 7                            Chartoff-Winkler Productions
# 8                                          Dovemead Films
# 9                                          United Artists
# 10                                    The Malpaso Company
# 11                                           C.A.T. Films
# 14                                      Filmways Pictures
# 15                                        Rastar Pictures
# 16                              Metro-Goldwyn-Mayer (MGM)
# 17                                              IPC Films
# 18                                  AVCO Embassy Pictures
# ...

# %% [markdown]
# ## Correlation and Regression Analysis

# %%
# scatter plot with budget vs gross

plt.scatter(x = movies_df['budget'], y = movies_df['gross'], alpha = 0.4, color = 'blue')

plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

plt.show()

# %%
# Plot Budget vs Gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = movies_df, scatter_kws = {'color': 'black'}, line_kws = {'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at the correlation 

movies_df.corr() # different kind of correlations : pearson=default, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
# high correlation between budget and gross

# %%
correlation_matrix = movies_df.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Let's look at the company field

df_numerized = movies_df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  month  correct_year
# 0  1048       55  19000000   46998772     2320    146.0    213             0
# 1   328       56   4500000   58853106      732    104.0    189             0
# 2  1746       56  18000000  538375067     1541    124.0    224             0
# 3  2247       56   3500000   83453539     1813     88.0    189             0
# 4   411       56   6000000   39846344     1778     98.0    195             0

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for All the Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score         0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes         0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget        0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# ...

# %%
correlation_matrix = df_numerized.corr()

corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#               score           0.016377
#               votes           0.013038
#               director        0.009079
#               writer          0.009081
#               star            0.006472
#               country        -0.010737
#               budget          0.020548
#               gross           0.006989
#               company         0.009211
#               runtime         0.008483
#               month          -0.011412
#               correct_year    0.009553
# rating        name           -0.008069
#               rating          1.000000
#               genre           0.072423
#               year            0.008779
#               released        0.016613
#               score           0.006192
#               votes           0.033743
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.334021
# budget        genre          -0.334021
# gross         genre          -0.234297
# genre         gross          -0.234297
#               votes          -0.145296
# votes         genre          -0.145296
# country       score          -0.133346
# score         country        -0.133346
# rating        gross          -0.095450
# gross         rating         -0.095450
# correct_year  genre          -0.082070
# genre         correct_year   -0.082070
# rating        budget         -0.081939
# budget        rating         -0.081939
# year          genre          -0.081261
# genre         year           -0.081261
# country       correct_year   -0.074166
# correct_year  country        -0.074166
# country       runtime        -0.073319
# runtime       country        -0.073319
# company       genre          -0.071067
# genre         company        -0.071067
# year          country        -0.070938
# country       year           -0.070938
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross         votes           0.632870
# votes         gross           0.632870
# gross         budget          0.750157
# budget        gross           0.750157
# correct_year  year            0.992136
# year          correct_year    0.992136
# released      month           0.999759
# month         released        0.999759
# name          name            1.000000
# writer        writer          1.000000
# runtime       runtime         1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# month         month           1.000000
# ...

# %% [markdown]
# ## Conclusion
# We can notice votes and budget fields have the highest correlation to gross earnings in the movies dataset.
